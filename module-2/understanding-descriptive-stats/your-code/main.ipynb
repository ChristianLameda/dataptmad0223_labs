# %% [markdown]
# # Understanding Descriptive Statistics
#
# Import the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import random
# %matplotlib inline
from random import randint
from IPython.display import display

# %% [markdown]
# ## Challenge 1
# #### 1.- Define a function that simulates rolling a dice 10 times. Save the information in a dataframe.
# **Hint**: you can use the *choices* function from module *random* to help you with the simulation.

# %%
# your code here
def dice_rolling():
    rolls = random.choices(range(1, 7), k=10)
    df = pd.DataFrame({'roll': rolls})
    return df

dice_rolls_df = dice_rolling()
dice_rolls_df
# Out:
#    roll
# 0     2
# 1     3
# 2     2
# 3     3
# 4     5
# 5     2
# 6     1
# 7     2
# 8     5
# 9     6

# %% [markdown]
# #### 2.- Plot the results sorted by value.

# %%
# your code here

sorted_df = dice_rolls_df.sort_values('roll')

plt.bar(sorted_df.index, sorted_df['roll'])
plt.xlabel('Roll Index')
plt.ylabel('Dice Roll Value')
plt.title('Sorted Dice Roll Results')
plt.show()

# %% [markdown]
# #### 3.- Calculate the frequency distribution and plot it. What is the relation between this plot and the plot above? Describe it with words.

# %%
# your code here

freq_dist = dice_rolls_df['roll'].value_counts().sort_index()

plt.bar(freq_dist.index, freq_dist.values)
plt.xlabel('Dice Roll Value')
plt.ylabel('Frequency')
plt.title('Dice Roll Frequency Distribution')
plt.show()

# %%
"""
The relation between this plot and the previous plot is that they both represent the same data, 
the dice rolls. However, the first plot showed the rolls sorted by value, while this plot shows the 
frequency distribution of the rolls.
"""
# Out:
# '\nThe relation between this plot and the previous plot is that they both represent the same data, \nthe dice rolls. However, the first plot showed the rolls sorted by value, while this plot shows the \nfrequency distribution of the rolls.\n'

# %% [markdown]
# ## Challenge 2
# Now, using the dice results obtained in *challenge 1*, your are going to define some functions that will help you calculate the mean of your data in two different ways, the median and the four quartiles.
#
# #### 1.- Define a function that computes the mean by summing all the observations and dividing by the total number of observations. You are not allowed to use any methods or functions that directly calculate the mean value.

# %%
# your code here

def mean(observations):
    total_sum = 0
    total_count = 0

    for observation in observations:
        total_sum += observation
        total_count += 1

    mean = total_sum / total_count
    return mean

# %% [markdown]
# #### 2.- First, calculate the frequency distribution. Then, calculate the mean using the values of the frequency distribution you've just computed. You are not allowed to use any methods or functions that directly calculate the mean value.

# %%
# your code here

def mean_frequency_dist(freq_dist):
    total_sum = 0
    count = 0
    for value, frequency in freq_dist.items():
        total_sum += value * frequency
        count += frequency
    mean = total_sum / count
    return mean

mean_frequency_dist(freq_dist)
# Out:
# 3.1

# %% [markdown]
# #### 3.- Define a function to calculate the median. You are not allowed to use any methods or functions that directly calculate the median value.
# **Hint**: you might need to define two computation cases depending on the number of observations used to calculate the median.

# %%
# your code here

def median(l):
    sorted_list = sorted(l.values)
    list_len = len(l)
    index = (list_len - 1) // 2
    if (list_len % 2):
        result = sorted_list[index]
    else:
        result = (sorted_list[index] + sorted_list[index + 1])/2
    return result[0]

median(dice_rolls_df)
# Out:
# 2.5

# %% [markdown]
# #### 4.- Define a function to calculate the four quartiles. You can use the function you defined above to compute the median but you are not allowed to use any methods or functions that directly calculate the quartiles.

# %%
# your code here

def quartiles(l):
    percentiles = [25,50,75,100]
    sorted_list = sorted(l.values)
    for p in percentiles:        
        k = (len(sorted_list)-1) * p/100
        f = math.floor(k)
        c = math.ceil(k)
        if f == c:
            print((p, sorted_list[int(k)][0]))
        else:
            print((p,((sorted_list[(f)]) + (sorted_list[(c)]))[0]/2))

quartiles(dice_rolls_df)
# Out:
# (25, 2.0)
# (50, 2.5)
# (75, 4.0)
# (100, 6)

# %% [markdown]
# ## Challenge 3
# Read the csv `roll_the_dice_hundred.csv` from the `data` folder.
# #### 1.- Sort the values and plot them. What do you see?

# %%
# your code here

roll_hundred = pd.read_csv('../data/roll_the_dice_hundred.csv')

roll_hundred = roll_hundred.drop('Unnamed: 0', axis=1)
sorted_values = roll_hundred['value'].sort_values()

plt.plot(sorted_values)
plt.xlabel('Roll Index')
plt.ylabel('Dice Roll Value')
plt.title('Sorted Dice Roll Values')
plt.show()

# %%
roll_hundred
# Out:
#     roll  value
# 0      0      1
# 1      1      2
# 2      2      6
# 3      3      1
# 4      4      6
# ..   ...    ...
# 95    95      4
# 96    96      6
# 97    97      1
# 98    98      3
# 99    99      6
#
# [100 rows x 2 columns]

# %%
"""
The data distribution is similar to the previous chart, but the differences between the number 
of times each value was rolled is not that big.
"""
# Out:
# '\nThe data distribution is similar to the previous chart, but the differences between the number \nof times each value was rolled is not that big.\n'

# %% [markdown]
# #### 2.- Using the functions you defined in *challenge 2*, calculate the mean value of the hundred dice rolls.

# %%
# your code here

mean = mean(roll_hundred['value'])
print(mean)
# Out:
# 3.74

# %% [markdown]
# #### 3.- Now, calculate the frequency distribution.

# %%
# your code here

frequency_dist2 = roll_hundred['value'].value_counts()
frequency_dist2
# Out:
# 6    23
# 4    22
# 2    17
# 3    14
# 1    12
# 5    12
# Name: value, dtype: int64

# %% [markdown]
# #### 4.- Plot the histogram. What do you see (shape, values...) ? How can you connect the mean value to the histogram?

# %%
# your code here

plt.bar(frequency_dist2.index, frequency_dist2.values)
plt.xlabel('Dice Roll Value')
plt.ylabel('Frequency')
plt.title('Dice Roll Frequency Distribution')
plt.show()

# %%
"""
The shape resembles the shape of the 10 rolls which is somewhat a Symmetrical shape. 
The mean value will be closer to 4
"""
# Out:
# '\nThe shape resembles the shape of the 10 rolls which is somewhat a Symmetrical shape. \nThe mean value will be closer to 4\n'

# %% [markdown]
# #### 5.- Read the `roll_the_dice_thousand.csv` from the `data` folder. Plot the frequency distribution as you did before. Has anything changed? Why do you think it changed?

# %%
# your code here

roll_thousand = pd.read_csv('../data/roll_the_dice_thousand.csv')
roll_thousand = roll_thousand.drop('Unnamed: 0', axis=1)

frequency_dist3 = roll_thousand['value'].value_counts().sort_index()
frequency_dist3
# Out:
# 1    175
# 2    167
# 3    175
# 4    168
# 5    149
# 6    166
# Name: value, dtype: int64

# %%
"""
The data distribution is more or less the same, but with less diference between occurences.
the shape is getting more and more symetrical with the increase of rolls.
"""
# Out:
# '\nThe data distribution is more or less the same, but with less diference between occurences.\nthe shape is getting more and more symetrical with the increase of rolls.\n'

# %% [markdown]
# ## Challenge 4
# In the `data` folder of this repository you will find three different files with the prefix `ages_population`. These files contain information about a poll answered by a thousand people regarding their age. Each file corresponds to the poll answers in different neighbourhoods of Barcelona.
#
# #### 1.- Read the file `ages_population.csv`. Calculate the frequency distribution and plot it as we did during the lesson. Try to guess the range in which the mean and the standard deviation will be by looking at the plot.

# %%
# your code here

ages = pd.read_csv('../data/ages_population.csv')
ages.hist()
print("Mean guess - Between 33 abd 41")
print("Standard Deviation guess - Around 10")
# Out:
# Mean guess - Between 33 abd 41
# Standard Deviation guess - Around 10

# %% [markdown]
# #### 2.- Calculate the exact mean and standard deviation and compare them with your guesses. Do they fall inside the ranges you guessed?

# %%
# your code here

ages_mean = ages.mean()
ages_std = ages.std()

print("Ages Mean", ages_mean)
print("Ages STD", ages_std)
# Out:
# Ages Mean observation    36.56
# dtype: float64
# Ages STD observation    12.8165
# dtype: float64

# %%
"""
The mean yes, the standard deviation not so much. But it is a close value. 
Graphical visualization helps a lot in the initial analysis
"""
# Out:
# '\nThe mean yes, the standard deviation not so much. But it is a close value. \nGraphical visualization helps a lot in the initial analysis\n'

# %% [markdown]
# #### 3.- Now read the file `ages_population2.csv` . Calculate the frequency distribution and plot it.

# %%
# your code here

ages2 = pd.read_csv("../data/ages_population2.csv")
ages2.hist()
# Out:
# array([[<Axes: title={'center': 'observation'}>]], dtype=object)

# %% [markdown]
# ####  4.- What do you see? Is there any difference with the frequency distribution in step 1?

# %%
"""
Yes. The range is quite shorter. But the type of distribution seems to be more or less the same, unimodal.
"""
# Out:
# '\nYes. The range is quite shorter. But the type of distribution seems to be more or less the same, unimodal.\n'

# %% [markdown]
# #### 5.- Calculate the mean and standard deviation. Compare the results with the mean and standard deviation in step 2. What do you think?

# %%
# your code here

ages2_mean = ages2.mean()
ages2_std = ages2.std()

print("Ages Mean", ages2_mean)
print("Ages STD", ages2_std)
# Out:
# Ages Mean observation    27.155
# dtype: float64
# Ages STD observation    2.969814
# dtype: float64

# %%
"""
Both values are much smaller. Especially the standard deviation.
It seems that this study (ages2 dataset) is much more specific than the first one (ages dataset).
Also because the range of data is quite less.
"""
# Out:
# '\nBoth values are much smaller. Especially the standard deviation.\nIt seems that this study (ages2 dataset) is much more specific than the first one (ages dataset).\nAlso because the range of data is quite less.\n'

# %% [markdown]
# ## Challenge 5
# Now is the turn of `ages_population3.csv`.
#
# #### 1.- Read the file `ages_population3.csv`. Calculate the frequency distribution and plot it.

# %%
# your code here

ages3 = pd.read_csv('../data/ages_population3.csv')
ages3.hist()
# Out:
# array([[<Axes: title={'center': 'observation'}>]], dtype=object)

# %% [markdown]
# #### 2.- Calculate the mean and standard deviation. Compare the results with the plot in step 1. What is happening?

# %%
# your code here

ages3_mean = ages3.mean()
ages3_std = ages3.std()

print("Ages Mean", ages3_mean)
print("Ages STD", ages3_std)
# Out:
# Ages Mean observation    41.989
# dtype: float64
# Ages STD observation    16.144706
# dtype: float64

# %%
"""
Both Average and standard deviation increased making the histogram a bit more skewed to the right. 
Altough the range is the same as is the first dataset. This neighborhood has more older people.
"""
# Out:
# '\nBoth Average and standard deviation increased making the histogram a bit more skewed to the right. \nAltough the range is the same as is the first dataset. This neighborhood has more older people.\n'

# %% [markdown]
# #### 3.- Calculate the four quartiles. Use the results to explain your reasoning for question in step 2. How much of a difference is there between the median and the mean?

# %%
# your code here

print(ages3['observation'].quantile([0.25,0.50,0.75,1]))
print("Difference:", ages3.mean()-ages3.median())
# Out:
# 0.25    30.0
# 0.50    40.0
# 0.75    53.0
# 1.00    77.0
# Name: observation, dtype: float64
# Difference: observation    1.989
# dtype: float64

# %%
"""
Compared to other neighbourhoods this one has indeed "older" people than other neighbourhoods. 
50% of the populations is more that 40years old.
"""
# Out:
# '\nCompared to other neighbourhoods this one has indeed "older" people than other neighbourhoods. \n50% of the populations is more that 40years old.\n'

# %% [markdown]
# #### 4.- Calculate other percentiles that might be useful to give more arguments to your reasoning.

# %%
# your code here

print(ages3['observation'].quantile([0.1,0.5,0.9]))
# Out:
# 0.1    22.0
# 0.5    40.0
# 0.9    67.0
# Name: observation, dtype: float64

# %%
"""
I think this percentiles will help the analysis. 
A lot of "outliers" are removed with these intervals
"""
# Out:
# '\nI think this percentiles will help the analysis. \nA lot of "outliers" are removed with these intervals\n'

# %% [markdown]
# ## Bonus challenge
# Compare the information about the three neighbourhoods. Prepare a report about the three of them. Remember to find out which are their similarities and their differences backing your arguments in basic statistics.

# %%
# your code here

display(ages.describe())
display(ages2.describe())
display(ages3.describe())
# Out:
#        observation
# count    1000.0000
# mean       36.5600
# std        12.8165
# min         1.0000
# 25%        28.0000
# 50%        37.0000
# 75%        45.0000
# max        82.0000
#        observation
# count  1000.000000
# mean     27.155000
# std       2.969814
# min      19.000000
# 25%      25.000000
# 50%      27.000000
# 75%      29.000000
# max      36.000000
#        observation
# count  1000.000000
# mean     41.989000
# std      16.144706
# min       1.000000
# 25%      30.000000
# 50%      40.000000
# 75%      53.000000
# max      77.000000

# %%
"""
From the 3 neighbourhoods we can easilly state that:
Neighbourhood 1 is probably a young family neighbourhood. We have a minimun age of 1, and 50% of the population is under the 40years old.
Neighbourhood 2 is probably a student neighbourhood, since the minimum age is 19 Years old and Max 36, which means that the Neighbourhood is quite young
Neighbourhood 3 is also a family neighbouhood, but with a few more older people with a increase in the 60-70 years old pop
"""
# Out:
# '\nFrom the 3 neighbourhoods we can easilly state that:\nNeighbourhood 1 is probably a young family neighbourhood. We have a minimun age of 1, and 50% of the population is under the 40years old.\nNeighbourhood 2 is probably a student neighbourhood, since the minimum age is 19 Years old and Max 36, which means that the Neighbourhood is quite young\nNeighbourhood 3 is also a family neighbouhood, but with a few more older people with a increase in the 60-70 years old pop\n'

# %%
ages2.describe()
# Out:
#        observation
# count  1000.000000
# mean     27.155000
# std       2.969814
# min      19.000000
# 25%      25.000000
# 50%      27.000000
# 75%      29.000000
# max      36.000000
