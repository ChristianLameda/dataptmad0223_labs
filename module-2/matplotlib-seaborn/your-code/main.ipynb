# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import math
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

# Matplot

plt.plot(x, y)
plt.show()

plt.plot(x, z, color='red', marker='o', linestyle='dashed',linewidth=3, markersize=1)
plt.show()

# %%
# Method 2

# Seaborn

sns.lineplot(x=x, y=y)
plt.show()

sns.lineplot(x=x, y=z)
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, ax = plt.subplots(nrows = 1,ncols = 2)
ax[0].plot(x, y)
ax[1].plot(x, z)
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

fig, ax = plt.subplots(nrows = 1,ncols = 2, figsize = (11,4))
ax[0].plot(x, y)
ax[1].plot(x, z)

ax[0].set_title('Chart 1', loc = "center", \
             fontdict = {'fontsize':8, 'fontweight':'bold', 'color':'tab:red'})
ax[1].set_title('Chart 2', loc = "center", \
             fontdict = {'fontsize':8, 'fontweight':'bold', 'color':'tab:green'})
ax[0].set_xlabel('X Axis')
ax[1].set_xlabel('X Axis')
ax[0].set_ylabel('Y Axis')
ax[1].set_ylabel('Y Axis')
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

y1 = x**2
y2 = np.exp(x)

# %%
figs, axs = plt.subplots(nrows = 2,ncols = 1, figsize = (11,10))
axs[0].plot(x,y1)
axs[1].plot(x,y2)
axs[0].set_yscale('linear')
axs[1].set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

figs, axs = plt.subplots(nrows = 2,ncols = 1, figsize = (11,10))
axs[0].plot(x,y1, label = "Label 1")
axs[1].plot(x,y2, label = "Label 2")
axs[0].set_yscale('linear')
axs[1].set_yscale('log')
axs[0].set_title('Chart 1', loc = "center", fontdict = {'fontsize':8, 'fontweight':'bold', 'color':'tab:blue'})
axs[1].set_title('Chart 2', loc = "center", fontdict = {'fontsize':8, 'fontweight':'bold', 'color':'tab:blue'})
plt.legend()
plt.show()

#No logro que me muestre la leyenda en el primer gráfico

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

# Importo mi dataset:
fitbit = pd.read_csv('../data/fitbit2.csv')

# Reemplazo los valores originales de la columna Work_or_Weekend (0,1) segùn sea el caso para que me devuelva
# si es Week o Weekend
fitbit['Work_or_Weekend'].replace({0: 'Weekend', 1: 'Week'}, inplace=True)

fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
monthly_steps = fitbit.groupby('Months_encoded')['Steps'].median()

# MEDIAN STEPS BY WORK_OR_WEEKEND
workdays_steps = fitbit.groupby('Work_or_Weekend')['Steps'].median()

# Construyo mi gráfico:
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

plt.sca(axs[0])
monthly_steps.plot(kind='bar')
plt.title('Average Steps by Month', fontdict={'fontsize': 9})
plt.xlabel('Month', fontdict={'fontsize': 8})
plt.ylabel('Avg Steps', fontdict={'fontsize': 8})
plt.xticks(rotation=0, fontsize=9)

plt.sca(axs[1])
workdays_steps.plot(kind='bar')
plt.title('Average Steps by Weekday/Weekend', fontdict={'fontsize': 9})
plt.xlabel('Day of Week', fontdict={'fontsize': 8})
plt.ylabel('Avg Steps', fontdict={'fontsize': 8})
plt.xticks(rotation=0, fontsize=9)

# Utilizo el metodo .savefig para guardar el gráfico
plt.savefig('../figures/charts.png', format='png')
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('../data/titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

print(titanic.dtypes)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
# Guardo en una variable solo los valores que sean del tipo int64 y float64

numerical_variables = titanic.select_dtypes(include=['int64', 'float64'])
print(numerical_variables)
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
# Guardo en una variable solo los valores que sean del tipo object

categorical_variables = titanic.select_dtypes(include=['object'])
print(categorical_variables)
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.style.use('classic')
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
# Use histograma ya que es el que mejor representa la distribucion de las edades.

plt.hist(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))

# Con 10 bins
axs[0].hist(titanic['Age'], bins=10)
axs[0].set_title('Bins = 10', fontsize= 10)

# Con 20 bins
axs[1].hist(titanic['Age'], bins=20)
axs[1].set_title('Bins = 20', fontsize= 10)

# Con 50 bins
axs[2].hist(titanic['Age'], bins=50)
axs[2].set_title('Bins = 50', fontsize= 10)

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here

A mayor numero de bins, mayor detalle de la distribucion de edades en el gráfico
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(data=titanic, x='Age')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

#Primero guardo en una variable los valores unicos de la columna Gender
gender_count = titanic['Gender'].value_counts()

# Utilizao grafico de barras, en el eje x uso el index de la columna gender, y en el eje y la suma de los valores
plt.bar(gender_count.index, gender_count.values)
plt.show()

# %%
# Method 2 - seaborn
# your code here

sns.countplot(x= 'Gender', data=titanic)
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

sns.countplot(x= 'Pclass', data=titanic)
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x=titanic['Age'], showfliers=True, showcaps=True, showmeans=True)
plt.show()

# %% [markdown]
# I use a box plot because with this chart we can see the the distribution of ages, and other info
# such as minimum, maximum, median

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
La media de edad es 30, la maxima es 60
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.violinplot(x=titanic['Age'])
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Adicional al boxplot, podemos usar violiin plot para ver tambien la distribucion de las edades.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.scatter(titanic["Age"], titanic["Fare"])
plt.title("Relationship between Fare and Age")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %%
# Method 2 - seaborn
# your code here

sns.regplot(x="Age", y="Fare", data=titanic)
plt.title("Relationship between Fare and Age")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.boxplot(x='Pclass', y='Age', data=titanic)
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
